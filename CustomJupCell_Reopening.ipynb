# %%
# IMPORTANT: This cell was generated by MicroStrategy for Jupyter.
# To ensure full functionality, please install the latest add-in version.
# (https://community.microstrategy.com/s/products)

# Import such a large cube my god from MicroStrategy
# MicroStrategy Tutorial/Profiles/a (a)/My Favorites/The Specific Favourites
# Cell Creation Date: 06/12/2020 11:12:15 AM

# %%
#test cell before

# %%
# IMPORTANT: This cell was generated by MicroStrategy for Jupyter.
# To ensure full functionality, please install the latest add-in version.
# (https://community.microstrategy.com/s/products)

# Import iris from MicroStrategy
# MicroStrategy Tutorial/Profiles/a (a)/My Reports
# Cell Creation Date: 06/10/2020 11:31:54 AM

# %%
#test cell between

# %%
# IMPORTANT: This cell was generated by MicroStrategy for Jupyter.
# To ensure full functionality, please install the latest add-in version.
# (https://community.microstrategy.com/s/products)

# Export/Update Cube iris in MicroStrategy
# MicroStrategy Tutorial/Profiles/a (a)/My Reports
# Cell Creation Date: 06/10/2020 12:57:31 PM

# %%
#test cell after
