# %%
# code importing iris from MicroStrategy

from mstrio.connection import Connection
from mstrio.cube import Cube
from mstrio.report import Report
from getpass import getpass

mstr_username = 'a'
mstr_password = ''
base_url = 'https://env-181971.customer.cloud.microstrategy.com/MicroStrategyLibrary/apiapi'
login_mode = 1
project_id = 'B7CA92F04B9FAE8D941C3E9B7E0CD754'

conn = Connection(base_url, mstr_username, mstr_password, project_id=project_id, login_mode=login_mode)

iris = Cube(conn, '69F2F26011EA5C801E8A0080EFC50272')
iris.apply_filters(attributes = None, metrics = None, attr_elements = None)
iris.to_dataframe()
iris_df = iris.dataframe

iris_df
# Out:
# Your connection to MicroStrategy Intelligence Server has been established.
# ...
#          Species  Id  PetalLengthCm  PetalWidthCm  \
# 0    Iris-setosa   1            0.0           0.2
# 1    Iris-setosa   0            9.0           0.1
# 2    Iris-setosa  11            9.0           0.2
# 3    Iris-setosa  12            1.6           0.2
# 4    Iris-setosa  13            0.0           0.1
# ..           ...  ..            ...           ...
# 195            x  50            0.0           0.2
# 196            x   6            1.7           0.4
# 197            x   7            0.0           0.3
# 198            x   8            9.0           0.2
# 199            x   9            0.0           0.2
#
#      Row Count - iris_created_with_rest_df  Row Count - iris_exported  \
# 0                                        1                          1
# 1                                        1                          1
# 2                                        1                          1
# ...

# %%
test_a = iris_df
test_asd = iris_df
glugah = iris_df
bebron_df = iris_df
