# %%
# code importing var_2M_30C from MicroStrategy

from mstrio.microstrategy import Connection
from mstrio.cube import Cube
from mstrio.report import Report
import getpass

mstr_username = 'mstr'
mstr_password = 'e2CtZDsx7Y9V'
base_url = 'https://env-174241.customer.cloud.microstrategy.com/MicroStrategyLibrary/api'
login_mode = 1
project_id = 'B7CA92F04B9FAE8D941C3E9B7E0CD754'

conn = Connection(base_url, mstr_username, mstr_password, project_id=project_id, login_mode=login_mode)
conn.connect()

var_2M_30C = Cube(conn, '3AF9822C11EA469000000080EF159EB9')
var_2M_30C.apply_filters(attributes = None, metrics = None, attr_elements = None)
var_2M_30C.to_dataframe()
var_2M_30C_df = var_2M_30C.dataframe

var_2M_30C_df
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Initializing an instance of a cube. Ple…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Connecting to MicroStrategy I-Server. P…
# HBox(children=(FloatProgress(value=0.0, max=80.0), HTML(value='')))
#            Category  City        Country  Customer ID  Customer Name  \
# 0          Category  City        Country  Customer ID  Customer Name
# 1          Category  City        Country  Customer ID  Customer Name
# 2          Category  City        Country  Customer ID  Customer Name
# 3          Category  City        Country  Customer ID  Customer Name
# 4          Category  City        Country  Customer ID  Customer Name
# ...             ...   ...            ...          ...            ...
# 1999995  Technology  Yuma  United States     GH-14410    Gary Hansen
# 1999996  Technology  Yuma  United States     GH-14410    Gary Hansen
# 1999997  Technology  Yuma  United States     GH-14410    Gary Hansen
# 1999998  Technology  Yuma  United States     GH-14410    Gary Hansen
# 1999999  Technology  Yuma  United States     TH-21235  Tiffany House
#
#          Customer Name23  Order Date Order Date2        Order ID Postal Code  \
# 0        Customer Name23                                Order ID
# 1        Customer Name23                                Order ID
# 2        Customer Name23                                Order ID
# 3        Customer Name23                                Order ID
# 4        Customer Name23                                Order ID
# ...                  ...         ...         ...             ...         ...
# 1999995      Gary Hansen  10/16/2017  10/16/2017  CA-2017-159282       85364
# 1999996      Gary Hansen  10/16/2017  10/16/2017  CA-2017-159282       85364
# 1999997      Gary Hansen  10/16/2017  10/16/2017  CA-2017-159282       85364
# 1999998      Gary Hansen  10/16/2017  10/16/2017  CA-2017-159282       85364
# 1999999    Tiffany House   5/14/2016   5/14/2016  CA-2016-108224       85364
#
#          ... Ship Date23       Ship Mode    State   State2  Sub-Category  \
# 0        ...                   Ship Mode    State   State2  Sub-Category
# 1        ...                   Ship Mode    State   State2  Sub-Category
# 2        ...                   Ship Mode    State   State2  Sub-Category
# 3        ...                   Ship Mode    State   State2  Sub-Category
# 4        ...                   Ship Mode    State   State2  Sub-Category
# ...      ...         ...             ...      ...      ...           ...
# 1999995  ...  10/21/2017  Standard Class  Arizona  Arizona      Machines
# 1999996  ...  10/21/2017  Standard Class  Arizona  Arizona      Machines
# 1999997  ...  10/21/2017  Standard Class  Arizona  Arizona      Machines
# 1999998  ...  10/21/2017  Standard Class  Arizona  Arizona      Machines
# 1999999  ...   5/14/2016        Same Day  Arizona  Arizona   Accessories
#
#         Discount    Profit   Profit2 Row Count - table1    Sales
# 0            NaN       NaN       NaN                  1      NaN
# 1            NaN       NaN       NaN                  1      NaN
# 2            NaN       NaN       NaN                  1      NaN
# 3            NaN       NaN       NaN                  1      NaN
# 4            NaN       NaN       NaN                  1      NaN
# ...          ...       ...       ...                ...      ...
# 1999995      0.7 -479.9880 -479.9880                  1  599.985
# 1999996      0.7 -479.9880 -479.9880                  1  599.985
# 1999997      0.7 -479.9880 -479.9880                  1  599.985
# 1999998      0.7 -479.9880 -479.9880                  1  599.985
# 1999999      0.2   48.7011   48.7011                  1  185.528
#
# [2000000 rows x 31 columns]

# %%
# code importing iris_exported from MicroStrategy

from mstrio.microstrategy import Connection
from mstrio.cube import Cube
from mstrio.report import Report

mstr_username = 'mstr'
mstr_password = 'admin'
base_url = 'https://env-167618.customer.cloud.microstrategy.com/MicroStrategyLibrary/api'
login_mode = 1
project_id = 'B7CA92F04B9FAE8D941C3E9B7E0CD754'

conn = Connection(base_url, mstr_username, mstr_password, project_id=project_id, login_mode=login_mode)
conn.connect()

iris_exported = Cube(conn, '9387758811E9F5A100000080EFE53DC8')
iris_exported.apply_filters(attributes = None, metrics = None, attr_elements = None)
iris_exported.to_dataframe()
iris_exported_df = iris_exported.dataframe

iris_exported_df
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Initializing an instance of a cube. Ple…
#       Id          Species  PetalLengthCm  PetalWidthCm  Row Count - iris  \
# 0      1      Iris-setosa            1.4           0.2                 1
# 1     10      Iris-setosa            1.5           0.1                 1
# 2    100  Iris-versicolor            4.1           1.3                 1
# 3    101   Iris-virginica            6.0           2.5                 1
# 4    102   Iris-virginica            5.1           1.9                 1
# ..   ...              ...            ...           ...               ...
# 145   95  Iris-versicolor            4.2           1.3                 1
# 146   96  Iris-versicolor            4.2           1.2                 1
# 147   97  Iris-versicolor            4.2           1.3                 1
# 148   98  Iris-versicolor            4.3           1.3                 1
# 149   99  Iris-versicolor            3.0           1.1                 1
#
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.1
# 2              5.7           2.8
# 3              6.3           3.3
# 4              5.8           2.7
# ..             ...           ...
# 145            5.6           2.7
# 146            5.7           3.0
# 147            5.7           2.9
# 148            6.2           2.9
# 149            5.1           2.5
#
# [150 rows x 7 columns]

# %%
import pandas as pd

dataframe_names={}
for el in dir():
    if isinstance(locals()[el], pd.core.frame.DataFrame) and el[0]!='_':
        dataframe_names[el] = locals()[el]

dataframe_names

# %%
second_copy = iris_exported_df

# %%
import pandas as pd

def create_custom_env():
    output={}
    for el in globals().keys():
        if el[0]!='_' and isinstance(globals()[el], pd.core.frame.DataFrame):
            output[el] = globals()[el]
    return output

test = create_custom_env()
test

# %%
def test():
    return globals()

test() == locals()

# %%
def t():
    return dir()

dir() == dir(globals())

# %%
locals().keys()

# %%
create_custom_env

# %%
mstrio_env

# %%
iris_exported_df

# %%
del mstrio_env['iris_exported_df']

# %%
import pandas as pd

def create_custom_env():
    output={}
    for el in globals().keys():
        if el[0]!='_' and isinstance(globals()[el], pd.core.frame.DataFrame):
            output[el] = globals()[el]
    return output

def update_custom_env():
    global mstrio_env
    new_mstrio_env = mstrio_env
    for el in globals().keys():
        if el[0]!='_' and isinstance(globals()[el], pd.core.frame.DataFrame) and not hasattr(new_mstrio_env, el):
            new_mstrio_env[el] = globals()[el]
    return new_mstrio_env

    
update_custom_env()

# %%
if mstrio_env:
    mstrio_env = update_custom_env()
else:
    mstrio_env = create_custom_env()
    
mstrio_env

# %%
# code exporting iris_temp_env to MicroStrategy

### This code does not apply any Data Modeling Steps ###
### If it should, please use the connector addon to prepare data ###

from mstrio.microstrategy import Connection
from mstrio.dataset import Dataset
import getpass

mstr_username = input('username: ')
mstr_password = getpass.getpass('password: ')
base_url = 'https://env-167618.customer.cloud.microstrategy.com/MicroStrategyLibrary/api'
login_mode = 1
project_id = 'B7CA92F04B9FAE8D941C3E9B7E0CD754'

conn = Connection(base_url, mstr_username, mstr_password, project_id=project_id, login_mode=login_mode)
conn.connect()

dataset = Dataset(conn, name="iris_temp_env", description="this is cool!")
dataset.add_table(name="iris", data_frame=mstrio_env['iris'], update_policy="add", to_metric=["PetalLengthCm","PetalWidth","SepalWidthCm"], to_attribute=["Id","Species","SepalLengthCm"])
dataset.create(folder_id="E28804DA11E5B55F088C0080EF555BA1")

# %%
iris_exported_df.replace('', pd.np.nan).dropna().replace(pd.np.nan, '')[:10].to_json(orient='records')
